# %%
import numpy as np
import pandas as pd
import time
import timeit
import copy 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import gc
from joblib import Parallel, delayed
import scipy as sp
import librosa
import librosa.display
import seaborn as sns
import os
import sys
import pylab
import tracemalloc
from collections import Counter
import linecache
import matplotlib.pyplot as plt

# %%
# Definitions
total_samples = 629145480
data_dir = "/home/slow-storage/Kaggle/Earthquake/"
train_file = data_dir + "train.csv"
plot_dir=data_dir + "images/plot/"

test_dir=data_dir + "test/"
test_plot_dir = data_dir + "images_test/plot/"
batch_size=150000
slide_ruler=10000

# %%
#traindf.describe()

# %%
def get_plot(traindf,plotdir,index,batch_size,slide):
    
    if index > 62899:
        sys.exit()
    
    begining = index*slide
    end = begining+batch_size
    print(index,":",begining,end)
    
    placeholders = np.arange(begining,end)
    df = traindf.iloc[placeholders]
    
    plt.plot(df)
    plt.axis('off')
    plt.savefig(plotdir + str(index) + '.png')
    plt.cla()
    plt.clf()
    plt.close()

# %%
def get_plot_test(testdir,file,plotdir):
    
    df = pd.read_csv(testdir + file,
                      dtype={'acoustic_data': np.int16},
                     )

    plt.plot(df)
    plt.axis('off')
    plt.savefig(plotdir + file + '.png')
    plt.cla()
    plt.clf()
    plt.close()

    #return y

# %%
def display_top(snapshot, key_type='lineno', limit=3):
    snapshot = snapshot.filter_traces((
        tracemalloc.Filter(False, "<frozen importlib._bootstrap>"),
        tracemalloc.Filter(False, "<unknown>"),
    ))
    top_stats = snapshot.statistics(key_type)

    print("Top %s lines" % limit)
    for index, stat in enumerate(top_stats[:limit], 1):
        frame = stat.traceback[0]
        # replace "/path/to/module/file.py" with "module/file.py"
        filename = os.sep.join(frame.filename.split(os.sep)[-2:])
        print("#%s: %s:%s: %.1f KiB"
              % (index, filename, frame.lineno, stat.size / 1024))
        line = linecache.getline(frame.filename, frame.lineno).strip()
        if line:
            print('    %s' % line)

    other = top_stats[limit:]
    if other:
        size = sum(stat.size for stat in other)
        print("%s other: %.1f KiB" % (len(other), size / 1024))
    total = sum(stat.size for stat in top_stats)
    print("Total allocated size: %.1f KiB" % (total / 1024))

# %%
#tracemalloc.start()


traindf = pd.read_csv(train_file,
                      dtype={'acoustic_data': np.int16, 'time_to_failure': np.float64},
                      #nrows=100000000
                     )

# %%
plotloops=int(total_samples/slide_ruler)
print(plotloops)
# Out:
# 62914

# %%
labels = []
for i in range(0,plotloops):
    get_plot(traindf,plot_dir,i,batch_size,slide_ruler)

print(labels)
# Out:
# 0 : 0 150000
# 1 : 10000 160000
# 2 : 20000 170000
# 3 : 30000 180000
# 4 : 40000 190000
# 5 : 50000 200000
# 6 : 60000 210000
# 7 : 70000 220000
# 8 : 80000 230000
# 9 : 90000 240000
# 10 : 100000 250000
# 11 : 110000 260000
# 12 : 120000 270000
# 13 : 130000 280000
# 14 : 140000 290000
# 15 : 150000 300000
# 16 : 160000 310000
# 17 : 170000 320000
# 18 : 180000 330000
# 19 : 190000 340000
# 20 : 200000 350000
# 21 : 210000 360000
# 22 : 220000 370000
# 23 : 230000 380000
# 24 : 240000 390000
# 25 : 250000 400000
# 26 : 260000 410000
# 27 : 270000 420000
# 28 : 280000 430000
# 29 : 290000 440000
# 30 : 300000 450000
# 31 : 310000 460000
# 32 : 320000 470000
# 33 : 330000 480000
# 34 : 340000 490000
# 35 : 350000 500000
# 36 : 360000 510000
# 37 : 370000 520000
# 38 : 380000 530000
# 39 : 390000 540000
# 40 : 400000 550000
# 41 : 410000 560000
# 42 : 420000 570000
# 43 : 430000 580000
# 44 : 440000 590000
# 45 : 450000 600000
# 46 : 460000 610000
# 47 : 470000 620000
# ...

# %%
print(len(labels))
# Out:
# 62900

# %%
with open(data_dir + 'librosa_train_labels.csv', 'w') as f:
    for item in labels:
        f.write("%s\n" % item)

# %%
testfilenames = os.listdir(test_dir)
testfilenames.sort()

# %%
for file in testfilenames:
    get_plot_test(test_dir,file,test_plot_dir)
